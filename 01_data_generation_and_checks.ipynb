# %% [markdown]
# # 01 — Data Generation & Quality Checks\n\nThis notebook generates a **virtual simulation** climate dataset and performs basic quality checks.\n\n**Outputs you can screenshot for GitHub proof:**\n- df.head()\n- df.info()\n- missing values table (before preprocessing)\n

# %%
import pandas as pd\nfrom src.data.make_dataset import generate_synthetic_climate_dataset\nfrom src.data.preprocess import preprocess_climate_data\n\nraw_df = generate_synthetic_climate_dataset(seed=42)\nraw_df.head()

# %%
raw_df.info()

# %%
# Missing values BEFORE preprocessing\nraw_df.isna().sum()

# %%
clean_df = preprocess_climate_data(raw_df)\nclean_df.isna().sum()

# %% [markdown]
# Next: open `02_eda_and_trends.ipynb` to create EDA charts and trend metrics.
